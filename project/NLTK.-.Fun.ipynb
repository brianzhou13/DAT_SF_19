# %% [markdown]
# # NLTK Items

# %% [markdown]
# # RUN THROUGH ALGOS. Need a better understanding of our data.
#
# 1. countvectorize the content.
# 2. fit_transform the information
# 3. print shape (rows is pages, and features is columns)
# 4. term frequency: TfidfTransformer(use_idf=False).fit(X_train_counts)
#     * applying TFIDF to docs
#     * fitting the MultinomialNB() #BernoulliNB()
#         why did we use this classifier
# 5. For your 'pipelines' code, why did you use a train_size of 0.7, and a random_state of 42
#
# Q1: Can you help go over your sqlite and how you stored everything into DB? the code-wise?
# Q2: How do you write an API? My original project was for NYT, but I don't know how to parse in the data.
# Q3: What other libraries/packages/concepts should I know about? [Topic modeling?]
# Q5: Best practices on how to scrape body content (storing procedure, etc.)

# %% [markdown]
# MASHABLE IDEAS:
#
#     We could crawl the pages in their current categories of technology/bus, and then see how they score in those specific sectors (?) See how it changes against time.
#
#     Naive Bayes seem to be a good and solid classifier for texts
#
#     We can also conduct a sentiment analysis to see which types of documents are posted when, and which types of documents tend to do better.
#
#     We could build a recommender system of users selecting what types of articles they like to read, and then serve them articles that could work with them.
#
#
# TextBlob: - sentiment.
#
# LDA:
# * Clean the documents
#     - Tokenizing: converting a document to its atomic elements
#     - Stopping: removing meaningless words
#     - Stemming: merging words that are equivalent in meaning
#
# Which types of methods in NLTK are very powerful?
#
# What types of studies users tend to use in NLTK?
#
# Best way to do bulk text data? SHould I be doing it all into the scraping-code, or should I be storing it all into a database?

# %%
import nltk

#from mashable import mashable.mash
#define a class and pass in the dataset


import pandas as pd
import numpy as np

from sklearn import cross_validation
from sklearn.feature_extraction.text import CountVectorizer

# %%
test_text = ["""Daqri, an AR smart helmet startup, is growing its leadership board significantly today 
while it continues testing its device The company is adding three new executive positions today: Mike Lynch, 
who most recently tackled talent acquisition and human resources at SpaceX, will be joining Daqri as chief human 
potential officer; Roy Ashok, a former product management leader at Qualcomm, will be coming aboard as chief product 
officer; and Patrick Alo, a marketing leader from Virgin Group, will be appointed as chief marketing officer.These 
latest hires will give Daqri improved flexibility as it looks to aggressively hire top talent and expand the company’s 
brand presence in the enterprise community.

The device itself doubles as a safety helmet and set of safety glasses in addition to providing mixed reality work 
instructions, safety information, mapping and more” for industrial workers. The helmet is already being tested with 
some major corporations, including Autodesk, GE, Topcon, Hyperloop and KSP Steel.

The LA-based startup gathered headlines at CES 2016 when it unveiled its enterprise-focused augmented reality 
helmet. Our own Sarah Lane sat down with the Daqri team to discuss potential use cases for the device and the 
future of AR tech in the workplace."""]

#Leave here as a piece of test text that we can use.

# %%
#words = [nltk.word_tokenize(word) for word in test_text]

x_new_counts = CountVectorizer(decode_error = 'ignore') #what is this decode_error?

x_new_counts.fit(test_text)

x_new_counts.get_feature_names()
type(x_new_counts)
# Out:
# sklearn.feature_extraction.text.CountVectorizer

# %%
x_new_counts_transform = x_new_counts.transform(test_text) #transforming the dataset

# %%
x_new = pd.DataFrame(x_new_counts_transform.toarray(), columns = x_new_counts.get_feature_names())

x_new
# Out:
#    2016  aboard  acquisition  adding  addition  aggressively  alo  already  \
# 0     1       1            1       1         1             1    1        1
#
#    an  and    ...      use  virgin  when  while  who  will  with  work  \
# 0   1    7    ...        1       1     1      1    1     4     2     1
#
#    workers  workplace
# 0        1          1
#
# [1 rows x 133 columns]

# %%
#importing a .json file for NLP parsing

import json
from pprint import pprint

with open('mashable/mashable/items1.json') as data_file:
    data = json.load(data_file)
    #seems like there is something wrong with 'extra data'
    
    #when it comes to checking json, you can also use [jsonlint]: http://jsonlint.com/
    
#pprint(data)

#data is printed.

# %%
data[0]["h1"]
data[0]["author"]
len(data)
# Out:
# 100

# %%
#define the columns
#data input could be optimized with better for-loop logic.



h1_col = []
title_col = []
url_col = []
auth_col = []
desc_col = []
body_cont = []


#for loop to turn a list to a string
#then strip the string of the '[]' pulled in from the scraper
for value in range(len(data)):
    
    h1_col.append((''.join(data[value]['h1'])).strip('[]'))
    title_col.append((''.join(data[value]['title'])).strip('[]'))
    url_col.append((''.join(data[value]['url'])).strip('[]'))
    auth_col.append((''.join(data[value]['author'])).strip('[]'))
    desc_col.append((''.join(data[value]['description'])).strip('[]'))
    body_cont.append((''.join(data[value]['body_content']).strip('[]')))
    #did not add in the content idea
    
    ##

# %%
text_pd = pd.DataFrame()
text_pd['url_id'] = range(len(data))
text_pd['url'] = url_col
text_pd['h1'] = h1_col
text_pd['author'] = auth_col
text_pd['description'] = desc_col
text_pd['title'] = title_col
text_pd['url'] = url_col
text_pd['body'] = body_cont

# %%
text_pd #need to remove the '[]'
# Out:
#     url_id                                                url  \
# 0        0  http://mashable.com/2013/01/07/amazon-instant-...
# 1        1  http://mashable.com/2013/01/07/ap-samsung-spon...
# 2        2  http://mashable.com/2013/01/07/astronaut-notre...
# 3        3  http://mashable.com/2013/01/07/apple-40-billio...
# 4        4   http://mashable.com/2013/01/07/beewi-smart-toys/
# 5        5   http://mashable.com/2013/01/07/att-u-verse-apps/
# 6        6  http://mashable.com/2013/01/07/chuck-hagel-web...
# 7        7   http://mashable.com/2013/01/07/crayon-creatures/
# 8        8  http://mashable.com/2013/01/07/cosmic-events-d...
# 9        9      http://mashable.com/2013/01/07/creature-cups/
# 10      10          http://mashable.com/2013/01/07/dad-jokes/
# 11      11  http://mashable.com/2013/01/07/downton-abbey-t...
# 12      12  http://mashable.com/2013/01/07/earth-size-plan...
# 13      13          http://mashable.com/2013/01/07/echo-game/
# 14      14  http://mashable.com/2013/01/07/entrepreneur-tr...
# 15      15  http://mashable.com/2013/01/07/facebook-sick-app/
# 16      16  http://mashable.com/2013/01/07/felt-audio-puls...
# 17      17       http://mashable.com/2013/01/07/ford-glympse/
# 18      18   http://mashable.com/2013/01/07/ftc-google-leaks/
# 19      19  http://mashable.com/2013/01/07/fujifilm-50x-su...
# 20      20  http://mashable.com/2013/01/07/hillary-clinton...
# 21      21             http://mashable.com/2013/01/07/htc-q1/
# 22  Intel Shows the Awesome Laptop You'll Be Using...
# 23    Masimo's iSpO2 Lets Your iPhone Take Your Pulse
# 24  Canon PowerShot N Thinks Creatively So You Don...
# 25  Need a Job? Check 100+ Openings at Edelman and...
# 26  Infographic: The Self-Driving, Ultra-Connected...
# 27  LG Sets Price on Its 55" OLED TV and It's a Doozy
# 28                       How to Land a Job at Spotify
# 29   6 of Lionel Messi's Greatest Moments in Fashion
# ..                                                ...
# 70  Turn Your Windows 8 Laptop Into a Touchscreen ...
# 71   BodyMedia Fitness Armband Gets a Fashion Upgrade
# 72  Didn't Get Obama Inauguration Tickets? Blame T...
# 73   Toshiba Shows Off Its New 84-inch Ultra HD 4K TV
# 74                   Traffic Signals Inspired by Bugs
# 75          Inside YouTube's Plan to Dominate Your TV
# 76                               VH1 Unveils New Logo
# 77                    Top 10 Twitter Pics of the Week
# 78  Japanese Cat Carries Clues to Bizarre Bomb Hac...
# 79  The Imaginary War: Why Cable and YouTube Shoul...
# 80  NFL Star Uses Twitter Avatar to Send Trash Tal...
# 81  Apply for Scholarships in a Flash With 'Person...
# 82  Lego-Inspired iPhone 5 Cases Will Make You Gee...
# 83  Artist Looks for Drone Pilots on Craigslist, G...
# 84       Ro Marley Talks Sustainable Tech at CES 2013
# 85                   Samsung Shows Off Curved OLED TV
# 86         15 Snow Dogs That Will Melt Your Icy Heart
# 87  'Star Trek Into Darkness' Mobile App Will Blas...
# 88     Star Wars Episode VII: Who Will Direct it Now?
# 89  T-Mobile Brings Free Data to Windows 8 Laptops...
# 90  T-Mobile to Expand Value Plans and Let You Upg...
# 91            50 Cent Talks Tech With Mashable at CES
# 92                   So What's Up for Amazon in 2013?
# 93  Apple Refuses to Make the Device That's Taking...
# 94              'Arrested Development' Returns in May
# 95      9 Terrible Instagram Filters You'll Never Use
# 96  NBC Comedy '1600 Penn' Launches Social Media C...
# 97  Beam Remote Sends Your Head Anywhere in the World
# 98                        The Anatomy of a 4chan Hoax
# 99               Watch Pixar's 'Blue Umbrella' Teaser
#
#                                                  body
# 0   <section class="article-content">\n\n<p>Having...
# 1   <section class="article-content">\n\n<p>The <a...
# 2   <section class="article-content">\n\n<p>When i...
# 3   <section class="article-content">\n\n<p>It loo...
# 4   <section class="article-content">\n\n<div clas...
# 5   <section class="article-content">\n\n<p>LAS VE...
# 6   <section class="article-content">\n\n<p>Mere h...
# 7   <section class="article-content">\n\n<p>If a k...
# 8   <section class="article-content">\n\n<p>Take a...
# 9   <section class="article-content">\n\n<p>Cream ...
# 10  <section class="article-content">\n\n<p><ifram...
# 11  <section class="article-content">\n\n<div clas...
# 12  <section class="article-content">\n\n<p>The Mi...
# 13  <section class="article-content">\n\n<p><ifram...
# 14  <section class="article-content">\n\n<p>Entrep...
# 15  <section class="article-content">\n\n<p>Feelin...
# 16  <section class="article-content">\n\n<p>LAS VE...
# 17  <section class="article-content">\n\n<p>LAS VE...
# 18  <section class="article-content">\n\n<p>Rep. D...
# 19  <section class="article-content">\n\n<p>LAS VE...
# 20  <section class="article-content">\n\n<p>On her...
# 21  <section class="article-content">\n\n<p><a hre...
# 22  <section class="article-content">\n\n<div clas...
# 23  <section class="article-content">\n\n<div clas...
# 24  <section class="article-content">\n\n<p>LAS VE...
# 25  <section class="article-content">\n\n<p>Whethe...
# 26  <section class="article-content">\n\n<p>What w...
# 27  <section class="article-content">\n\n<div clas...
# 28  <section class="article-content">\n\n<p>New ye...
# 29  <section class="article-content">\n\n<p>Lionel...
# ..                                                ...
# 70  <section class="article-content">\n\n<p>LAS VE...
# 71  <section class="article-content">\n\n<p>LAS VE...
# 72  <section class="article-content">\n\n<p>Lookin...
# 73  <section class="article-content">\n\n<p>LAS VE...
# 74  <section class="article-content">\n\n<p>Why do...
# 75  <section class="article-content">\n\n<p>Quick:...
# 76  <section class="article-content">\n\n<p></p>\n...
# 77  <section class="article-content">\n\n<div clas...
# 78  <section class="article-content">\n\n<p>Japan'...
# 79  <section class="article-content">\n\n<p>Tradit...
# 80  <section class="article-content">\n\n<p>Did <a...
# 81  <section class="article-content">\n\n<p>Fillin...
# 82  <section class="article-content">\n\n<div clas...
# 83  <section class="article-content">\n\n<div clas...
# 84  <section class="article-content">\n\n<div clas...
# 85  <section class="article-content">\n\n<p>LAS VE...
# 86  <section class="article-content">\n\n<div clas...
# 87  <section class="article-content">\n\n<p>Movie ...
# 88  <section class="article-content">\n\n<p>Is the...
# 89  <section class="article-content">\n\n<p>T-Mobi...
# 90  <section class="article-content">\n\n<p>LAS VE...
# 91  <section class="article-content">\n\n<div clas...
# 92  <section class="article-content">\n\n<p>Among ...
# 93  <section class="article-content">\n\n<p>One ca...
# 94  <section class="article-content">\n\n<p><em><a...
# 95  <section class="article-content">\n\n<div clas...
# 96  <section class="article-content">\n\n<p>NBC an...
# 97  <section class="article-content">\n\n<div clas...
# 98  <section class="article-content">\n\n<p>When t...
# 99  <section class="article-content">\n\n<p><ifram...
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Tokenization
#
# Tokenization segments a document into its atomic elements. In this case, we are interested in tokenizing to words. This can be done with NLTK's tokenize.regexp module
#
#
# ## Stop Words
#
# Stop words need to be removed from our token list. For below example, we are using the stop_words package from Pypi.
# conservative stop-list: https://github.com/Alir3z4/stop-words/blob/master/english.txt
#
#
# # Stemming
#
# Stemming words is a technique used to reduce topically similar words to their root. The Porter stemming algorithm is the most widely used method.
#
# http://tartarus.org/~martin/PorterStemmer/

# %%
import nltk

from textblob import TextBlob

from nltk.tokenize import RegexpTokenizer #nltk tokenizer
from stop_words import get_stop_words #nltk stop_words
from nltk.stem.porter import PorterStemmer #nltk stemmer


test1 = ''.join(text_pd.h1[0])
test1 = test1.strip('[]') #this code is stripping out the '[]'

#TOKENIZER
tokenizer = RegexpTokenizer(r'\w+') #tokenizer

#STOP WORDS
en_stop = get_stop_words('en') #list of stopwords

#STEMMING
p_stemmer = PorterStemmer() 

test_pd2 = text_pd.head(100)

#print test_pd2

for value in range(len(test_pd2)):
    #have a holder variable (test_text)
    
    #print "this is the original length of the string %s" % len(test_pd2.description[value]) 
    #we are printing the length of the description associated with each url
    
    test_text = tokenizer.tokenize(test_pd2.body[value])
    test_text = [i for i in test_text if not i in en_stop] #remove stop words
    test_text = [p_stemmer.stem(i) for i in test_text]
    
    test_pd2.body[value] = test_text
    
    test_text = tokenizer.tokenize(test_pd2.description[value])
    test_text = [i for i in test_text if not i in en_stop] #remove stop words
    test_text = [p_stemmer.stem(i) for i in test_text]
    
    test_pd2.description[value] = test_text
    
    test_text = tokenizer.tokenize(test_pd2.title[value])
    test_text = [i for i in test_text if not i in en_stop] #remove stop words
    test_text = [p_stemmer.stem(i) for i in test_text]
    
    test_pd2.title[value] = test_text
# Out:
# /Users/brianzhou/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/brianzhou/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/brianzhou/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test_pd2.description[0]
type(test_pd2.description[0])
# Out:
# list

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-c305fe7587f1> in <module>()
#       3 for value in range(len(test_pd2)):
#       4     #checking matching urls, and for those that don't match, then we can drop.
# ----> 5     test = unicodedata.normalize('NFKD', test_pd2.description[value]).encode('ascii','ignore') #not certain what this does.
#       6     test_pd2.description[value] = test
#       7
#
# TypeError: must be unicode, not list

# %% [markdown]
# # Interesting Code:
#
#
# #### To see longtail keywords -->  long_words = [w for w in V if len(w) > 15]
# #### We are able to obtain the vocabulary of a text 't' using sorted(set(x))

# %%
from nltk.collocations import *

fdist_1 = nltk.FreqDist(test_pd2.body[0])
#fdist_1.plot() #this frequency distribution may become interesting when we have to cross-compare articles
#fdist_1.tabulate()

#b_grams = list(bigrams()

# %% [markdown]
# # Constructing a Document-Term Matrix
#
# Text should be cleaned (tokenized / stopped / stemmed) lists of lists of our documents.
#
# To generate a LDA model, we need to understand how frequently each term occurs within each document. To do that, we need to construct a document-term matrix with a package called gensim

# %%
import gensim

from gensim import corpora, models

dictionary = corpora.Dictionary(texts)
#traverses tokens_h1, assigning a unique integer id to each unique token, while also collecting word-counts

corpus = [dictionary.doc2bow(text) for text in texts]

#the doc2bow() function converts dictionary into a bag-of-words
#the result, corpus, is a list of vectors equal to the number of documents. each document is a series of tuples.
#next the uniqueID must be converted into a 'bag-of-words' model 
#https://en.wikipedia.org/wiki/Bag-of-words_model

print dictionary.token2id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-8fa116a59207> in <module>()
#       3 from gensim import corpora, models
#       4
# ----> 5 dictionary = corpora.Dictionary(texts)
#       6 #traverses tokens_h1, assigning a unique integer id to each unique token, while also collecting word-counts
#       7
#
# NameError: name 'texts' is not defined

# %% [markdown]
# ## Applying the LDA model
#
# corpus is a document-term matrix, and we are ready to generate the LDA model:

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = 1, id2word = dictionary, passes = 20)

#num_topics is the number of requested latent topics to be extracted from the training corpus.
#id2word is a mapping from word ids (integers) to words (strings).
#passes is the number of laps the model will go through the corpus. more passes, the more accurate


#It is used to determine the vocabulary size, as well as for debugging and topic printing.
#get_document_topics(xxx) return topic distribution for the given document bow, as a list of (topic_id, topic_proba)
#get_topic_terms: Returns a list of (word_id, probability) 2-tuples for the most probable words in topic
#print_topics (num_topics=10, num_words=10)

# %%
print(ldamodel.print_topics(num_topics=1, num_words=3))

ldamodel.print_topics(num_topics=10, num_words=10)

#we can see that we need to

# %%
#dictionary = []
#corpus = []

#for value in range(len(tokens_h1)):
    
#    dictionary[value] = corpora.Dictionary(tokens_h1[value])
#    corpus[value] = [dictionary.doc2bow(value2) for value2 in tokens_h1[value]]
    
#    ldamodel[value] = gensim.models.ldamodel.LdaModel(corpus[value], 
#                    num_topics = 1, id2word = dictionary[value], passes = 20)

# %%
#test module
dictionary = []
corpus = []
tokens_h1 = []

for value in range(len(text_pd)):

    tokens_h1.append(tokenizer.tokenize(text_pd.h1[value])) #tokenize h1
    tokens_h1[value] = [i for i in tokens_h1[value] if not i in en_stop] #stop words not working
    tokens_h1[value] = [p_stemmer.stem(i) for i in tokens_h1[value]] #stem

for x in range(len(text_pd)):
    tokens_dict = tokens_h1[value] #adding in here since current won't work
    #dictionary = corpora.Dictionary(tokens_h1)
    dictionary = corpora.Dictionary(tokens_dict)
    corpus = [dictionary.doc2bow(value3) for value3 in tokens_dict
    
#LDA Model
ldamodel = gensim.models.ldamodel.LdaModel(corpus[0], num_topics = 1, id2word = dictionary, passes = 20)
    
print(ldamodel.print_topics(num_topics=1, num_words=3))

ldamodel.print_topics(num_topics=10, num_words=10)

# %% [markdown]
# # TEXT BELOW IS ABOUT BLOB

# %%
from textblob import TextBlob

test1 = ''.join(test_pd2.description[4]) #joins a list into a string
test1 = test1.strip('[]') #this code is stripping out the '[]'
#print test1

#print test_pd2.body[4]


#print test2
#test3 = ''.join(test2)


blob1 = TextBlob(test1) #test1 is h1 @ 0

# %%
blob1.noun_phrases

# %%
#LDA Model
ldamodel = gensim.models.ldamodel.LdaModel(corpus[0], num_topics = 1, id2word = dictionary, passes = 20)
    
print(ldamodel.print_topics(num_topics=1, num_words=3))

ldamodel.print_topics(num_topics=10, num_words=10)

# %%
blob1 #we can pull th

# %%
blob1.sentiment #polarity is negative.

# %%
blob3 = TextBlob(text_pd.description[2])

# %%
blob_list = []

for value in text_pd.description:
    blob_list.append(value)

# %%
type(blob_list[1])

# %%
type(blob1)

# %%
text_pd.description[2]

# %%
blob1.ngrams()

# %%
#from textblob import TextBlob
import textblob as tb

tb.blob.BaseBlob(text_pd.description[0]) #what did this do (?)


#blob1.classify()

# %%
import nltk, re, pprint
from __future__ import division #not sure
from nltk import word_tokenize
from nltk.corpus import wordnet as wn
wn.synsets('motorcar')

# %%
from urllib2 import Request

url = "http://techcrunch.com/"
#response = request.urlopen(url)
#raw = response.read().decode('utf8')#
#type(raw)

html = Request.urlopen(url).read().decode('utf8')
html[:60]

# %%
from bs4 import BeautifulSoup


raw = BeautifulSoup(html).get_text()
tokens = word_tokenize(raw)
tokens
